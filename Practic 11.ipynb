# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data = pd.read_csv('C:\\Users\\Steph\\GeekBrains\\titanic.csv', delimiter=',')
data
# Out:
#       PassengerID                                           Name PClass  \
# 0               1                   Allen, Miss Elisabeth Walton    1st
# 1               2                    Allison, Miss Helen Loraine    1st
# 2               3            Allison, Mr Hudson Joshua Creighton    1st
# 3               4  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st
# 4               5                  Allison, Master Hudson Trevor    1st
# ...           ...                                            ...    ...
# 1308         1309                             Zakarian, Mr Artun    3rd
# 1309         1310                         Zakarian, Mr Maprieder    3rd
# 1310         1311                               Zenni, Mr Philip    3rd
# 1311         1312                               Lievens, Mr Rene    3rd
# 1312         1313                                 Zimmerman, Leo    3rd
#
#         Age     Sex  Survived  SexCode
# 0     29.00  female         1        1
# ...

# %%
ff = data.groupby(['Sex']).count()
# data['Survived'].plot(kind='pie')
ff['Name'].plot(kind='pie',title='Соотношение полов на корабле', ylabel = 'sex')
# Out:
# <AxesSubplot:title={'center':'Соотношение полов на корабле'}, ylabel='sex'>

# %%
ff = data.groupby(['Sex','Survived']).count()

# ff['Name'].plot(kind='pie')
ff

ff['Name'].plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Name'>

# %%
ff = data.groupby(['PClass','Survived']).count()

# ff['Name'].plot(kind='pie')
ff

ff['Name'].plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Name'>

# %%
gg = pd.crosstab(data["Sex"],data['Survived']).apply(lambda r: r/len(data), axis=1)
gg[1].plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='1'>

# %%
gg.plot(kind='pie',subplots=True)
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>], dtype=object)

# %%
gg[0].plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='0'>

# %%
group_data_hz = data.groupby(['PClass','Survived'])['PassengerID'].count()

group_data_hz.hist()

group_data_hz
# Out:
# PClass  Survived
# *       0             1
# 1st     0           129
#         1           193
# 2nd     0           160
#         1           119
# 3rd     0           573
#         1           138
# Name: PassengerID, dtype: int64

# %%
sex_class_sur = data.pivot_table(index=['Sex'], columns=[ 'PClass','Survived'], values='PassengerID', aggfunc='count')
female_sex = sex_class_sur.loc['female', ['1st', '2nd', '3rd']]

female_sex.plot()
female_sex
# Out:
# PClass  Survived
# 1st     0             9.0
#         1           134.0
# 2nd     0            13.0
#         1            94.0
# 3rd     0           132.0
#         1            80.0
# Name: female, dtype: float64

# %%
sex_class_sur
# Out:
# PClass      *    1st           2nd          3rd
# Survived    0      0      1      0     1      0     1
# Sex
# female    NaN    9.0  134.0   13.0  94.0  132.0  80.0
# male      1.0  120.0   59.0  147.0  25.0  441.0  58.0

# %%
male_sex  = sex_class_sur.loc['male',['1st','2nd','3rd']]
# male_sex.plot()
male_sex
# male_sex['PassengerID'].plot(kind='pie', figsize=(7,7),
#                   autopct='%1.1f%%',
#                   shadow=True)
# Out:
# PClass  Survived
# 1st     0           120.0
#         1            59.0
# 2nd     0           147.0
#         1            25.0
# 3rd     0           441.0
#         1            58.0
# Name: male, dtype: float64

# %%
# data.sort_values('Age')
age_bins = [0, 8, 18, 32, 45, 60]
age_srez
pd.cut(data['Age'],bins=age_bins)

# # age_srez.hist()

# age_srez2 = data['Survived']
# age_srez['Survived'] = data['Survived']
# age_srez
# age_srez3 = age_srez2['Survived'] = age_srez['Age']
# age_srez.columns
# age_srez.to_csv('my_new_csv.csv')
# Out:
# 0       (18, 32]
# 1         (0, 8]
# 2       (18, 32]
# 3       (18, 32]
# 4         (0, 8]
#           ...
# 1308    (18, 32]
# 1309    (18, 32]
# 1310    (18, 32]
# 1311    (18, 32]
# 1312    (18, 32]
# Name: Age, Length: 1313, dtype: category
# Categories (5, interval[int64, right]): [(0, 8] < (8, 18] < (18, 32] < (32, 45] < (45, 60]]

# %%
qq = pd.DataFrame(data)
for i in qq['Age']:
    if i < 20:
       i = '0 - 20'
    else :
        i = '20+'
        
qq
# Out:
#       PassengerID                                           Name PClass  \
# 0               1                   Allen, Miss Elisabeth Walton    1st
# 1               2                    Allison, Miss Helen Loraine    1st
# 2               3            Allison, Mr Hudson Joshua Creighton    1st
# 3               4  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st
# 4               5                  Allison, Master Hudson Trevor    1st
# ...           ...                                            ...    ...
# 1308         1309                             Zakarian, Mr Artun    3rd
# 1309         1310                         Zakarian, Mr Maprieder    3rd
# 1310         1311                               Zenni, Mr Philip    3rd
# 1311         1312                               Lievens, Mr Rene    3rd
# 1312         1313                                 Zimmerman, Leo    3rd
#
#         Age     Sex  Survived  SexCode
# 0     29.00  female         1        1
# ...

# %%
ff = data.groupby(['Survived']).count()
# data['Survived'].plot(kind='pie')
ff['Sex'].plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Sex'>
